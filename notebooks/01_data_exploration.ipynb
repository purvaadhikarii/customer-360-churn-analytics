# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("C:/Users/preeti adhikari/OneDrive/Purva Adhikari/OneDrive/Desktop/customer-360-churn-analytics/data/raw/telco_customer_churn_synthetic.csv")
df.head()
# Out:
#   customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  CUST00000    Male              1      No         No      52           No
# 1  CUST00001    Male              1      No         No      70           No
# 2  CUST00002    Male              0     Yes         No      50          Yes
# 3  CUST00003    Male              1      No        Yes      67           No
# 4  CUST00004  Female              0      No         No      66           No
#
#       MultipleLines InternetService       OnlineSecurity  ...  \
# 0  No phone service              No                  Yes  ...
# 1                No             DSL                  Yes  ...
# 2  No phone service              No  No internet service  ...
# 3               Yes              No  No internet service  ...
# 4  No phone service             DSL                  Yes  ...
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0                   No  No internet service  No internet service
# ...

# %%
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5000 non-null   object
#  1   gender            5000 non-null   object
#  2   SeniorCitizen     5000 non-null   int64
#  3   Partner           5000 non-null   object
#  4   Dependents        5000 non-null   object
#  5   tenure            5000 non-null   int64
#  6   PhoneService      5000 non-null   object
#  7   MultipleLines     5000 non-null   object
#  8   InternetService   5000 non-null   object
#  9   OnlineSecurity    5000 non-null   object
#  10  OnlineBackup      5000 non-null   object
#  11  DeviceProtection  5000 non-null   object
#  12  TechSupport       5000 non-null   object
#  13  StreamingTV       5000 non-null   object
#  14  StreamingMovies   5000 non-null   object
#  15  Contract          5000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
sns.countplot(x='Churn', data=df)
plt.title("Churn Distribution")
plt.show()

df['Churn'].value_counts(normalize=True)
# Out:
# Churn
# No     0.733
# Yes    0.267
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['tenure'], kde=True)
plt.title("Tenure Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['MonthlyCharges'], kde=True)
plt.title("Monthly Charges Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Contract', hue='Churn', data=df)
plt.title("Churn by Contract Type")
plt.xticks(rotation=40)
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(numeric_only=True), cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
insights = [
    "1. Churn rate is roughly 27%, consistent with real telecom churn.",
    "2. Customers with Month-to-Month contracts churn the most.",
    "3. High Monthly Charges customers churn more often.",
    "4. Short tenure (<12 months) customers show higher churn.",
    "5. Fiber optic internet users have higher churn probability.",
]

for i in insights:
    print(i)
# Out:
# 1. Churn rate is roughly 27%, consistent with real telecom churn.
# 2. Customers with Month-to-Month contracts churn the most.
# 3. High Monthly Charges customers churn more often.
# 4. Short tenure (<12 months) customers show higher churn.
# 5. Fiber optic internet users have higher churn probability.
